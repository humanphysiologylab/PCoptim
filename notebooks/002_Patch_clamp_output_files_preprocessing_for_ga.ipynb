# %%
import matplotlib.pyplot as plt
import sys
import os

# %%
sys.path.append('../src/python_func/')
from file_processing import trace_from_atf, trace_from_abf, protocol_from_abf, initial_state_protocol_from_abf

# %% [markdown]
# ### How it works
#
# If you want to read file.atf (or save it in the format appropriate to ga) - use function
# >*trace_from_atf*(path, save, new_path)
#
# where :
#
# &emsp; *path*  - is path to file.atf
#
# &emsp;  *save* - True/False, if you want to save your trace in file
#
# &emsp;  *new_path* - path there you want to save your trace(default path to trace is PCoptim/data/traces)
#
#
# If you want to read file.abf use
# >*trace_from_abf*(path, save, new_path).
#
# You can also get the protocol:
# >*protocol_from_abf*(path, save, new_path)
#
# and potential between sweeps:
# >*initial_protocol_from_abf*(path, save, new_path)
#
# for ga optimization from the file.abf.
#
# By default imported data is saved in subdirectories *protocols, initial_protocols* and *traces* of PCoptim/data directory. The setting 'save' parameter to False imports the data without saving the CSV.

# %%
atf_path = '../data/raw_data/test_atf.atf'
atf = trace_from_atf(atf_path, save=False)
plt.plot(atf)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb9ea1c09d0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0a30>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0b50>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0c70>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0d90>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0eb0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0fd0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3130>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3250>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3370>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1c0a00>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3490>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d36a0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d37c0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d38e0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3a00>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3b20>,
#  <matplotlib.lines.Line2D at 0x7fb9ea1d3c40>]

# %% [markdown]
# ### Below you can try all of this functions.

# %%
save = False
new_name  = 'NEW_NAME.csv'

# %%
abf_path = '../data/raw_data/test_abf.abf'
abf = trace_from_abf(abf_path, 
               save = save,
               new_path = f'../data/traces/{new_name}')
plt.plot(abf)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb9ea08b640>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08b6a0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08b7c0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08b8b0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08b9d0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08baf0>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08bc10>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08bd30>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08be50>,
#  <matplotlib.lines.Line2D at 0x7fb9ea08bf70>]

# %%
protocol = protocol_from_abf(abf_path, 
                             save = save,
                             new_path = f'../data/protocols/{new_name}')
plt.plot(protocol)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb9e7d42580>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d425e0>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42700>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42820>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42940>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42a60>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42b80>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42ca0>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42dc0>,
#  <matplotlib.lines.Line2D at 0x7fb9e7d42ee0>]

# %%
initial_state_protocol = initial_state_protocol_from_abf(abf_path, 
                                             save = save,
                                             new_path = f'../data/initial_state_protocols/{new_name}')
plt.plot(initial_state_protocol)
